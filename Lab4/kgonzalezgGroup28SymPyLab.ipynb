# %% [markdown]
# <a href="https://colab.research.google.com/github/K-E-V-0/MetNumUN2023I/blob/main/Lab4/kgonzalezgGroup28SymPyLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ### **Our own polynomial**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10 - 121*x**9  + 5796*x**8 - 141666*x**7 + 1936389*x**6 - 15734649*x**5 + 78285374*x**4 - 237917804*x**3 + 424054680*x**2 -398664000*x +148176000

p, r = div(p,  x+28)

print(p)
print(r)
print()

p, r = div(p,  x+30)

print(p)
print(r)
print()

p, r = div(p,  x+35)

print(p)
print(r)
print()

p, r = div(p,  x+6)

print(p)
print(r)
print()
# Out:
# x**9 - 149*x**8 + 9968*x**7 - 420770*x**6 + 13717949*x**5 - 399837221*x**4 + 11273727562*x**3 - 315902289540*x**2 + 8845688161800*x - 247679667194400
# 6935030829619200
#
# x**8 - 179*x**7 + 15338*x**6 - 880910*x**5 + 40145249*x**4 - 1604194691*x**3 + 59399568292*x**2 - 2097889338300*x + 71782368310800
# -2401150716518400
#
# x**7 - 214*x**6 + 22828*x**5 - 1679890*x**4 + 98941399*x**3 - 5067143656*x**2 + 236749596252*x - 10384125207120
# 435226750560000
#
# x**6 - 220*x**5 + 24148*x**4 - 1824778*x**3 + 109890067*x**2 - 5726484058*x + 271108500600
# -12010776210720

# %%
p = x**10 - 121*x**9  + 5796*x**8 - 141666*x**7 + 1936389*x**6 - 15734649*x**5 + 78285374*x**4 - 237917804*x**3 + 424054680*x**2 -398664000*x +148176000

p, r = div(p,  x+35)

print(p)
print(r)
# Out:
# x**9 - 156*x**8 + 11256*x**7 - 535626*x**6 + 20683299*x**5 - 739650114*x**4 + 25966039364*x**3 - 909049295544*x**2 + 31817149398720*x - 1113600627619200
# 38976022114848000

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x\*\*10 - 121\*x\*\*9  + 5796\*x\*\*8 - 141666\*x\*\*7 + 1936389\*x\*\*6 - 15734649\*x\*\*5 + 78285374\*x\*\*4 - 237917804\*x\*\*3 + 424054680\*x\*\*2 -398664000\*x +148176000)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 121*x**9  + 5796*x**8 - 141666*x**7 + 1936389*x**6 - 15734649*x**5 + 78285374*x**4 - 237917804*x**3 + 424054680*x**2 -398664000*x +148176000)
# Out:
# (x - 35)*(x - 30)*(x - 28)*(x - 7)*(x - 6)*(x - 5)*(x - 4)*(x - 3)*(x - 2)*(x - 1)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - x\*\*10 - 121\*x\*\*9  + 5796\*x\*\*8 - 141666\*x\*\*7 + 1936389\*x\*\*6 - 15734649\*x\*\*5 + 78285374\*x\*\*4 - 237917804\*x\*\*3 + 424054680\*x\*\*2 -398664000\*x +148176000 = 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 121*x**9  + 5796*x**8 - 141666*x**7 + 1936389*x**6 - 15734649*x**5 + 78285374*x**4 - 237917804*x**3 + 424054680*x**2 -398664000*x +148176000, 0), x)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 28, 30, 35}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(x**2*pi - (pi+sqrt(8))+ (sqrt(2)+pi), 0), x)
# Out:
# {-2**(1/4)/sqrt(pi), 2**(1/4)/sqrt(pi)}

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 121*x**9  + 5796*x**8 - 141666*x**7 + 1936389*x**6 - 15734649*x**5 + 78285374*x**4 - 237917804*x**3 + 424054680*x**2 -398664000*x +148176000,domain='GF(3)')
# Out:
# x**3*(x - 1)**4*(x + 1)**3

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations

# %% [markdown]
# ![Captura web_1-4-2023_214111_www.wolframalpha.com.jpeg](data:image/jpeg;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, y1, z1 = symbols("x1 y1 z1 ", real=True)  
x = 28 + I*x1
y = 30 + I*y1
z = 35 + I*z1

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))

w = N(1/(pi + I), 20)
print('w=',w)
# Out:
# (I*x1 + 28)*(I*y1 + 30)*(I*z1 + 35)
# -I*x1*y1*z1 - 35*x1*y1 - 30*x1*z1 + 1050*I*x1 - 28*y1*z1 + 980*I*y1 + 840*I*z1 + 29400
# -I*x1*y1*z1 - 35*x1*y1 - 30*x1*z1 + 1050*I*x1 - 28*y1*z1 + 980*I*y1 + 840*I*z1 + 29400
# -I*x1*y1*z1 - 35*x1*y1 - 30*x1*z1 + 1050*I*x1 - 28*y1*z1 + 980*I*y1 + 840*I*z1 + 29400
# w= 0.28902548222223624241 - 0.091999668350375232456*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
#
# ![Captura web_1-4-2023_221529_www.wolframalpha.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Captura web_1-4-2023_222651_www.wolframalpha.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# ![Captura web_1-4-2023_22181_chat.openai.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## SymPy’s integrate

# %% [markdown]
# **Our own integral**
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import cos, sin, ln
from math import e
x = Symbol('x')
integrate(e**(cos(x))*sin(x)+ln(x**2 + 2*x + 2), x)
# Out:
# -1.0*2.71828182845905**cos(x) + x*log(x**2 + 2*x + 2) - 2*x + log(x**2 + 2*x + 2) + 2*atan(x + 1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin, cos, ln
from math import e
x = Symbol('x')
integrate(e**(cos(x))*sin(x)+ln(x**2 + 2*x + 2), (x,e,100))
# Out:
# -206.803566572364 - 1.0*2.71828182845905**cos(100) + 2*atan(101) + 101*log(10202)

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(e**(cos(x))*sin(x)+ln(x**2 + 2*x + 2), (x,e,100)))
# Out:
# 726.213822734799
